# %% [markdown]
# # Activity # 1

# %% [markdown]
# # Car

# %%
class Car:
    def __init__(self,color,type_,hp,torque,transmission):
        self.color_=color
        self.type__=type_
        self.hp_=hp
        self.torque_=torque
        self.transmission_=transmission
        self.locked=True
        self.pothole=True
        self.brake=True
        self.steer_forw=True
        self.steer_left=True
        self.steer_right=True
        self.accelerate=True
        self.skid=True
    def lock(lock_):
        if lock_.locked==True:
            print("multiple beeps,car is already locked")
        else:
            lock_.locked==False
            lock_.locked=True
            print("beep,car is locked")            
    def unlock(unlock_):
        if unlock_.locked==False:
            print("multiple beeps,car is already unlocked")
        else:
            unlock_.locked==True
            unlock_.locked=False
            print("beep,car is unlocked")   
    def AEB(aeb):
        if aeb.pothole==True:
            aeb.brake==True
            print("Brakes applied to avoid accident")
        else:
            pass
    def accelerate(accelerate_):
        if accelerate==True:
            print("already accelerated")
        else:
            accelerate==False
            accelerate=True
            Print("accelerated")
    def brake(brake_):
        if brake==True:
             print("brake already applied")
        else:
            brake==False
            brake=True
            Print("brake applied")       
    def ABS(abs):
        if skid==True:
            brake==True
            print("ABS applied to avoid accident")
        else:
            pass
    def steer_forward(steer_forw):
        if steer_left==True or steer_right==True:
            steer_forw=True
        else:
            print("Already going straight")

# %% [markdown]
# # Drone

# %%
class Drone:
    def __init__(drone,chassis,material,IC,m1,m2,m3,m4,battery):
        drone.chassis_=chassis
        drone.material_=material
        drone.IC_=IC
        drone.battery_=battery
        drone.motor1=m1
        drone.motor2=m2
        drone.motor3=m3
        drone.motor4=m4
        drone.hovered=True
    def hover(hover_):
        if hover_.hovered==True:
            hovered=True
            print("max height reached")
        else:
            hover_.hovered==False
            hovered=True
            print("all motors getting equal max power to lift up drone")
    def land(land_):
        if land_.hovered==False:
            hovered=False
            print("drone already landed")
        else:
            land_.hovered==True
            hovered=False
            print("landing drone")
    def mov_f(mov_f_):
        if mov_f_.hovered==True:
            print("apply current greater to m3 and m4 to move forward")
        else:
            print("already moving forward")
    def mov_b(mov_b_):
        if mov_f_.hovered==True:
            print("apply current greater to m1 and m2 to move backward")
        else:
            mov_b.hovered==True
            print("already moving backward")
    def mov_b(mov_l_):
        if mov_l_.hovered==True:
            print("apply current greater to m1 and m4 to move left")
        else:
            mov_l.hovered==True
            print("already moving to left")    
    def mov_b(mov_r_):
        if mov_r_.hovered==True:
            print("apply current greater to m2 and m3 to move right")
        else:
            mov_r.hovered==True
            print("already moving to right")

# %%
d1=Drone("aluminium","plastic","rongfuda","coreless_12v","coreless_12v","coreless_12v","coreless_12v","12v")

# %% [markdown]
# # Animal

# %%
#                        ________________Animal________________
class Animal:
#                                     Consructor
    def __init__(self, is_alive, position, food_eaten):
        self.is_alive = is_alive
        self.position = position
        self.food = food_eaten
#                                    Methods
    def eat(eat_,choice):
        print("Happy to see you come for eating!")
        self.choice = str(input("what you want to eat? :"))
        is_routine = str(input("Did you eat {} daily? y/n :".format(choice)))
        if is_routine == 'y':
            print("Enjoy your meal!")            
        elif is_routine == 'n' :
            # you can simple use not available but make some loop to repeatdly  ask
            choice = print("{} is not available today, only enter which is availible!, run away and come again. ".format(choice))         
    def drink(drink_):
        print("Happy to see you come for drinking!")
        choice = str(input("what you want to drink? :"))
        is_routine = str(input("Did you eat {} daily? y/n :".format(choice)))
        if is_routine == 'y':
            print("Enjoy your meal!")
            
        elif is_routine == 'n' :
            # you can simple use not available but make some loop to repeatdly  ask
            choice = print("{} is not available today, only enter which is availible!, run away and come again. ".format(choice))

# %% [markdown]
# # COW

# %%
class Cow():
#                                         Constructor
    def __init__(self, give_milk, resting):
        self.give_milk = give_milk
        self.resting = resting
#                                         Methods
    def eating(self):
        if food_eaten == True:
            eat_ = str(input("what you want to eat? :"))
            print("Cow is eating {}".format(eat_))
        elif food_eaten != True:
            print("no food is avaialble")
        else:
            print("error in cow, eating")
    def giving_milk(self):
        if is_alive == True:
            print("milk is collected.")
        elif is_alive == False:
                print("cow is not alive")
        else:
            print("error in giving milk of cow.")

# %% [markdown]
# # Shark

# %%
class Shark():
#                                        Constructor
    def __init__(self, sleeping, moving):
        self.sleeping = sleeping
        self.moving = moving
#                                         Methods
    def eating(self):
        if is_alive == True:
            print("Shark is eating")
        else:
            print("dead shark did not eat any thing")
    def fighting(self):
        if moving == True:
            print("shark is fighting")
        else:
            print("already dead")

# %%
# All 5 classes can be copied from activity 2 but make some interesting

# %% [markdown]
# # Activity # 2

# %% [markdown]
# Multi-level Inheritence
# -----------------------

# %%
#                        Cake ----> line no: 6
#                  Cream Cake ---> line no: 115
#           Cherry Cream Cake ---> line no: 166
# Chocolate Cherry Cream Cake ---> line no: 190

#              _______________________Simple Cake_______________________
class Cake:
    
#                                      Constructor    
    def __init__(self, floor, egg, sugar, milk, baking_soda, temperature, is_baked):
        self.floor = floor
        self.egg = egg
        self.sugar = sugar
        self.milk = milk 
        self.baking_soda = baking_soda
        self.temperature = temperature
        self.is_baked = is_baked
        
#                                  Getters and Setters    
#     floor
# check wether this type of get & set logic works!
    def getfloor(self):
        return self.floor
    def setfloor(self,floor):
        if type(floor) == int :
            self.floor = floor
        else:          
            print("only int type is accepted!")
        self.floor = floor
        return self.floor
#     egg
    def getegg(self):
        return self.egg
    def setegg(self,egg):
        self.egg = egg
        return self.egg
#     sugar
    def getsugar(self):
        return self.sugar
    def setsugar(self,sugar):
        self.sugar = sugar
        return self.sugar
#     milk
    def getmilk(self):
        return self.milk
    def setmilk(self,milk):
        self.milk = milk
        return self.milk
#     baking_soda
    def getbaking_soda(self):
        return self.baking_soda
    def setfloor(self,baking_soda):
        self.baking_soda = baking_soda
        return self.baking_soda
#     temperature
    def gettemperature(self):
        return self.temperature
    def settemperature(self,temperature):
        self.temperature = temperature
        return self.temperature
#     is_baked
    def getis_baked(self):
        return self.is_baked
    def setis_baked(self,is_baked):
        self.is_baked = is_baked
        return self.is_baked
    
#                                            Methods
    def separate_whites(self):
        eggs = int(input("how many eggs you want to use? : "))
        white_ok = 0
        white_faulty = 0
        count = 0
        for each_egg in range(0,eggs):
            count += 1
            yolk = input("Yolk of egg {} is damaged? y/n :".format(count))
            if yolk == 'n':
                white_ok += 1
                print("white separated of selected egg.")
            elif yolk == 'y':
                white_faulty += 1
                print("bad 'egg'")
        return "Available whites: {}.".format(white_ok)                 
    def beat_eggs_whites(self):
        beat_quantity=0
        for whites in range(0,7,+1):
            beat_quantity+=1
            if beat_quantity==7:
                return "whites 'foam' is formed"  
    def mix(self):
        for_mixing = "floor", "egg", "sugar", "milk", "baking_soda"
        bowl = []
        for ingredient in for_mixing:
            each_ingredient = str(input("Did you want to add {} in the bowl? y/n :".format(each_ingredient)))
            if each_ingredient == 'y':
                bowl.append(ingredient)
            elif each_ingredient == 'n':
                pass
            else:
                print("Invalid answer.")
        return "Given below list of ingredients is mixed:\n\nBowl =",bowl
    def bake(self):
        mixture_avlbl = str(input("Cake mixture is available? y/n :"))
        if mixture_avlbl == 'y':
            in_oven = str(input("want to put in oven? y/n :"))
            if in_oven == 'y':
                time = int(input("Time in seconds: "))
                print("cake mixture is in oven for {} seconds, now some action is needed.".format(time))  
                oven_temp=float(input("Oven Temperature:"))
                if (oven_temp >= 163):
                    first_s_t=float(input("First Sensor Temperature:"))    #\\
                    second_s_t=float(input("Second Sensor Temperature:"))  #   =-- 's' is for sensor whereas 't' is for temperature .
                    third_s_t=float(input("Third Sensor Temperature:"))    #||
                    if (first_s_t >= 163) and (second_s_t >= 163) and (third_s_t >= 163):
                        return "Cake is Baked"
                    else:
                        return "Sensors Damaged"
                else:
                    return "Again oven the mixture and use oven at full microwave power."
            elif in_oven == 'n':
                return "Then why you call this function."
            else:
                return "Error when putting in oven."
        elif mixture_avlbl == 'n':
            return "First make your mixture."
        else:
            return "Error in mixture."                
#              ________________________Cream Cake________________________
class CreamCake(Cake):
#                                     Constructor
    def __init__(self,cream,floor, egg, sugar, milk, baking_soda, temperature, is_baked):
        Cake.__init__(self, floor, egg, sugar, milk, baking_soda, temperature, is_baked)      
        self.cream=cream    
#                                 Getters and Setters
    def getcream(self):
        return self.cream
    def setcream(self,cream):
        self.cream = cream
        return self.cream
    #                                       Methods   
    def add_cream(self):
        cake_baked = str(input("Cake is baked? y/n :"))
        cream_on_cake = 0
        avlbl_cream = int(input("How much cream is available in grams? :"))
        if cake_baked == 'y':
            machine_run = str(input("want to start cream spreading machine? y/n :"))
            if machine_run == 'y':
                user_want = int(input("how many gram cream you want to spread on cake? :"))
                if user_want <= avlbl_cream:
                    print("Machine is spreading cream, wait a while.")
                    for user_want in range(0,avlbl_cream) :
                        time.sleep(1)
                    return "{}g cream is spreaded on entire surface of cake.".format(user_want)
                elif user_want >= avlbl_cream:
                    return "Not enough creme is available."
                else:
                    return "Error in cream quantity."
            elif machine_run == 'y':
                return "go away, if you dont like cream."
            else:
                return "Error in eating cream."
        elif cake_baked == 'n':
            return "Go away, First bake your cake."
        else:
            return "Error in cake baking."
    def refrigerate(self):
        user_want = int(input("Enter temperature in celsius, which you want for cake"))
        t_d_s = int(input("Enter current temperature of cake : "))       # temperature dipstick sensor
        if ( t_d_s >= user_want ):                                       # "_s" indicates sensor working
            print("cotinuous beep, Cake is refrigerated.")
            ref_door_s = str(input("Refrigerator door opened/closed ? :"))
            if ref_door_s == 'opened':
                return "stop beep voice\n Enjoy the moment"
            else:
                pass
        else:
            return "Wait a while"
#                 _________________________CherryCreamCake_________________________
class CherryCreamCake(CreamCake):
#                                        Constructor
    def __init__(self,cherry):
        CreamCake.__init__(self, cream, floor, egg, sugar, milk, baking_soda, temperature, is_baked)
        self.cherry=cherry   
#                                 Getters and Setters
    def getcherry(self):
        return self.cherry
    def setcherry(self,cherry):
        self.cherry = cherry
        return self.cherry
#                                        Methods  
    def add_cherry(self):
        cherry_quantity = int(input("How many cherries did you want on cake?  : "))
        count = 0
        for chery in range(0,cherry_quantity):
            fresh = str(input("Picked Cherry is Fresh or not? (y/n) :"))
            count += 1
            if (chery <= cherry_quantity) and (fresh == 'y') :
                return "\nno:{} cherry is dropped on cake".format(count)
            elif fresh == 'n':
                return "\n{}cheery is not fresh, so thrown out!\n".format(count)
            else:
                return "error"                
#                 _________________Chocolate Cherry Cream Cake_________________
class ChocolateCherryCreamCake(CherryCreamCake):
#                                     Constructor
    def __init__(self,chocolate):
        CherryCreamCake.__init__(self ,cherry, cream, floor, egg, sugar, milk, baking_soda, temperature, is_baked)        
        self.chocolate=chocolate             
#                                 Getters and Setters
    def getchocolate(self):
        return self.chocolate
    def setchocolate(self,chocolate):
        self.chocolate = chocolate
        return self.chocolate
#                                        Methods  
    def add_chocolate(self):
        choc = int(input("how much grams chocolate you want to spread on cake? :"))
        if  choc < 1:
            return "Nothing to spread!"
        else:    
            u_l_s = input("using lazy susans? (y/n) :")
            if (choc >= 1) and (u_l_s == 'y'):
                return "Chocolate is spreaded perfectly, wow."
            elif (choc >= 1) and (u_l_s == 'n'):
                return "chocolate is spreaded but not suitable for serving!"
            else:
                return "something went wrong!"

# %%
# Can we use decorator instead of get and set>>>>> check it detailed..

# %% [markdown]
# # Hierarchical Inheritence

# %%
#                        ________________Animal________________
class Animal:
#                                     Consructor
    def __init__(self, is_alive, position, food_eaten):
        self.is_alive = is_alive
        self.position = position
        self.food = food_eaten
#                                    Methods
    def eat(eat_,choice):
        print("Happy to see you come for eating!")
        self.choice = str(input("what you want to eat? :"))
        is_routine = str(input("Did you eat {} daily? y/n :".format(choice)))
        if is_routine == 'y':
            print("Enjoy your meal!")            
        elif is_routine == 'n' :
            # you can simple use not available but make some loop to repeatdly  ask
            choice = print("{} is not available today, only enter which is availible!, run away and come again. ".format(choice))         
    def drink(drink_):
        print("Happy to see you come for drinking!")
        choice = str(input("what you want to drink? :"))
        is_routine = str(input("Did you eat {} daily? y/n :".format(choice)))
        if is_routine == 'y':
            print("Enjoy your meal!")
            
        elif is_routine == 'n' :
            # you can simple use not available but make some loop to repeatdly  ask
            choice = print("{} is not available today, only enter which is availible!, run away and come again. ".format(choice)) 
#                       __________________Herbivorous__________________
class Herbivorous(Animal):
#                                         Constructor
    def __init__(self, teeth, molars):
        Animal.__init__(is_alive, position)
        self.teeth = teeth
        self.molars = mlolars
#                                         Methods
    def hunt_me(self):
        n_o_p = str(input("name of predator? : ")) 
        s_o_p = int(input("speed of predator? : "))#         speed of predator (s_o_p)
        n_o_h = str(input("name of hunted animal? : "))
        s_o_h = int(input("speed of hunted animal? :"))#         speed of hunted (s_o_h)
        if s_o_p > s_o_h:
            print("{} has been hunted by {}.".format(n_o_s,n_o_p))
        elif s_o_p < s_o_h:
            print("{} cannot hunt {} due to its slow speed.".format(n_o_p,n_o_s))        
    def persistance_hunt_me(self):
        n_o_p = str(input("name of predator? : "))
        s_o_p = int(input("speed of predator? : ")) #         speed of predator (s_o_p)
        h_o_p = str(input("home place of predator? y/n: "))#         home place of predator (h_o_p)
        n_o_p_a = str(input("name of prey? : "))#         speed of prey animal(s_o_p_a)
        s_o_p_a = int(input("speed of prey? :"))
        if s_o_p > s_o_p_a and h_o_p == 'y':
            print("{} has been persistance hunted by {}.".format(n_o_p_a,n_o_p))
        elif s_o_p < s_o_p_a and h_o_p == 'n':
            print("{} cannot hunt {} due to its slow speed.".format(n_o_p,n_o_p_a))   
#                        _______________________Cow_______________________
class Cow(Herbivorous):
#                                         Constructor
    def __init__(self, give_milk, resting):
        Herbivorous.__init__(herbivore_teeth, molars, is_alive, position)
        self.give_milk = give_milk
        self.resting = resting
#                                         Methods
    def eating(self):
        if food_eaten == True:
            eat_ = str(input("what you want to eat? :"))
            print("Cow is eating {}".format(eat_))
        elif food_eaten != True:
            print("no food is avaialble")
        else:
            print("error in cow, eating")
    def giving_milk(self):
        if is_alive == True:
            print("milk is collected.")
        elif is_alive == False:
                print("cow is not alive")
        else:
            print("error in giving milk of cow.")
#                          _______________SahiwalCow_______________       
class SahiwalCow(Cow):
#                                       Constructor
    def __init__(self,hump, male):
        Cow.__init__(self, give_milk, resting, herbivore_teeth, molars, is_alive, position)
        self.hump = hump
        self.male = male
#                                         Methods
    def milking(self):
        if self.food_eaten == True:
            print("milk is available, now sahiwal cow is milking good!")
        else:
            print("want food first!")
    def grazing(self):
        if self.food == True:
            print("no need to eat more")
        else:
            print("grazing because need food")
#                        ______________________Carniovorous______________________
class Carnivorous(Animal):
#                                              Constructor
    def __init__(self, hunt, carnivore_teeth):
        Animal.__init__(is_alive, position, food_eaten)
        self.hunt = hunt
        self.carnivore_teeth = carnivore_teeth
#                                             Methods
    def hunt(self):
        if is_alive == True:
            name = str(input("name of hunting animal? :"))
            name_ = str(input("name of hunted animal? :"))
            print("{} is hunted by {}.".format(name_, name))
        else:
            print("lives didn't exist")
    def persistance_hunt(self):
        if is_alive == True:
            name = str(input("name of hunting animal? :"))
            name_ = str(input("name of hunted animal? :"))
            print("{} is persistance hunted by {}.".format(name_, name))
        else:
            print("lives didn't exist")
#                  _____________________Carnivorous_____________________
class Shark(Carnivorous):
#                                        Constructor
    def __init__(self, sleeping, moving):
        Carnivorous.__init__(is_alive, position, food_eaten, hunt, carnivore_teeth)
        self.sleeping = sleeping
        self.moving = moving
#                                         Methods
    def eating(self):
        if is_alive == True:
            print("Shark is eating")
        else:
            print("dead shark did not eat any thing")
    def fighting(self):
        if moving == True:
            print("shark is fighting")
        else:
            print("already dead")
#                   ________________________BlueShark________________________
class BlueShark(Shark):
#                                          Constructor
    def __init__(self, length, angry):
        Shark.__init__(is_alive, position, food_eaten, hunt, carnivore_teeth,  sleeping, moving)
        self.length = length
        self.angry = angry
#                                           Methods
    def fighting(self):
        if angry == True:
            print("blue whale is fighting.")
        else:
            print("not in mod of fight.")
    def hunting(self):
        if food_eaten == True:
            print("hunting.")
        else:
            print("do not want to eat more.")

# %% [markdown]
# # Multiple inheritance

# %%
class Animal:
    def __init__(self, is_alive, position, food_eaten):
        self.is_alive = is_alive
        self.position = position
        self.food = food_eaten
    def eat(eat_,choice):
        print("Happy to see you come for eating!")
        self.choice = str(input("what you want to eat? :"))
        is_routine = str(input("Did you eat {} daily? y/n :".format(choice)))
        if is_routine == 'y':
            print("Enjoy your meal!")     
        elif is_routine == 'n' :
            # think about this later----> you can simple use not available but make some loop to repeatdly  ask
            choice = print("{} is not available today, only enter which is availible!, run away and come again. ".format(choice))        
    def drink(drink_):
        print("Happy to see you come for drinking!")
        choice = str(input("what you want to drink? :"))
        is_routine = str(input("Did you eat {} daily? y/n :".format(choice)))
        if is_routine == 'y':
            print("Enjoy your meal!")     
        elif is_routine == 'n' :
            # you can simple use not available but make some loop to repeatdly  ask
            choice = print("{} is not available today, only enter which is availible!, run away and come again. ".format(choice))            
class Herbivorous(Animal): 
    def __init__(self, herbivore_teeth, molars):
        Animal.__init__(is_alive, position)
        self.hebivorous_teeth = hebivorous_teeth
        self.molars = mlolars        
    def hunted(self):
#         speed of predator (s_o_p)
        n_o_p = str(input("name of predator? : "))
        s_o_p = int(input("speed of predator? : "))
#         speed of hunted (s_o_h)
        n_o_h = str(input("name of hunted animal? : "))
        s_o_h = int(input("speed of hunted animal? :"))
        if s_o_p > s_o_h:
            print("{} has been hunted by {}.".format(n_o_s,n_o_p))
        elif s_o_p < s_o_h:
            print("{} cannot hunt {} due to its slow speed.".format(n_o_p,n_o_s))            
    def persistance_hunted(self):
        #         speed of predator (s_o_p)
        n_o_p = str(input("name of predator? : "))
        s_o_p = int(input("speed of predator? : "))
#         home place of predator (h_o_p)
        h_o_p = str(input("home place of predator? y/n: "))
#         speed of hunted (s_o_h)
        n_o_h = str(input("name of hunted animal? : "))
        s_o_h = int(input("speed of hunted animal? :"))
        if s_o_p > s_o_h and h_o_p == 'y':
            print("{} has been persistance hunted by {}.".format(n_o_s,n_o_p))
        elif s_o_p < s_o_h and h_o_p == 'n':
            print("{} cannot hunt {} due to its slow speed.".format(n_o_p,n_o_s))    
class Carniovorous(Animal):
    def __init__(self, hunt, carnivore_teeth):
        Animal.__init__(is_alive, position, food_eaten)
        self.hunt = hunt
        self.carnivore_teeth = carnivore_teeth
    def hunt(self):
        if is_alive == True:
            name = str(input("name of hunting animal? :"))
            name_ = str(input("name of hunted animal? :"))
            print("{} is hunted by {}.".format(name_, name))
        else:
            print("lives didn't exist")
    def persistance_hunt(self):
        if is_alive == True:
            name = str(input("name of hunting animal? :"))
            name_ = str(input("name of hunted animal? :"))
            print("{} is persistance hunted by {}.".format(name_, name))
        else:
            print("lives didn't exist")
class Omnivorous(Herbivorous, Carnivorous):
    def __init__(self, eating, position, in_forest):
        super.__init__(is_alive, position, food_eaten, hunt, carnivore_teeth,  herbivore_teeth, molars)
        self.eating = eating
        self.position = position
        self.in_forest = in_forest
    def eat_meat(self):
        if in_forest == True:
            print("eating meat")
        elif in_forest == False:
            print("no meat is available")       
    def eat_herb(self):
        if in_forest == True:
            print("no herb is available, need search.")
        elif in_forest == False:
            print("eating herb.")
